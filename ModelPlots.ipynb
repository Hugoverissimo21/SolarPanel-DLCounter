# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json

# %% [markdown]
# ---

# %%
with open("ModelBuild/Metadata (efnet (zulo40))/results.json") as json_file:
    metadata_zulo40 = json.load(json_file)

plt.figure(figsize=(15, 5))
plt.suptitle("Zulo40 - Loss vs Epoch (original)")
for fold in metadata_zulo40:
    print(f"{fold}")
    print(f"Model stopped at epoch {metadata_zulo40[fold]['Results']['model_from_epoch']}")

    plt.subplot(1, 3, int(fold.split(" ")[-1])+1)
    val_loss = metadata_zulo40[fold]['Results']['val_loss']
    train_loss = metadata_zulo40[fold]['Results']['train_loss']

    epochs = range(1, len(val_loss) + 1)
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.axvline(x=int(metadata_zulo40[fold]['Results']['model_from_epoch'][:2]), color='g', linestyle='--')
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')

plt.tight_layout()
plt.show()
# Out:
# Fold 0
# Model stopped at epoch 22 with mae 1.2288780212402344
# Fold 1
# Model stopped at epoch 25 with mae 1.1219252347946167
# Fold 2
# Model stopped at epoch 19 with mae 1.270377516746521

# %%
with open("ModelBuild/Metadata (efnet) 02/results.json") as json_file:
    metadata_zulo40 = json.load(json_file)

plt.figure(figsize=(15, 5))
plt.suptitle("Metadata 02 - Loss vs Epoch (lr 1e-5)")
for fold in metadata_zulo40:
    print(f"{fold}")
    print(f"Model stopped at epoch {metadata_zulo40[fold]['Results']['model_from_epoch']}")

    plt.subplot(1, 3, int(fold.split(" ")[-1])+1)
    val_loss = metadata_zulo40[fold]['Results']['val_loss']
    train_loss = metadata_zulo40[fold]['Results']['train_loss']

    epochs = range(1, len(val_loss) + 1)
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.axvline(x=int(metadata_zulo40[fold]['Results']['model_from_epoch'][:2]), color='g', linestyle='--')
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')

plt.tight_layout()
plt.show()
# Out:
# Fold 0
# Model stopped at epoch 24 with mae 1.2293729782104492
# Fold 1
# Model stopped at epoch 25 with mae 1.4788836240768433
# Fold 2
# Model stopped at epoch 24 with mae 1.7431524991989136

# %%
with open("ModelBuild/Metadata (efnet) 03/results.json") as json_file:
    metadata_zulo40 = json.load(json_file)

plt.figure(figsize=(15, 5))
plt.suptitle("Metadata 03 - Loss vs Epoch (maiores dropouts)")
for fold in metadata_zulo40:
    print(f"{fold}")
    print(f"Model stopped at epoch {metadata_zulo40[fold]['Results']['model_from_epoch']}")

    plt.subplot(1, 3, int(fold.split(" ")[-1])+1)
    val_loss = metadata_zulo40[fold]['Results']['val_loss']
    train_loss = metadata_zulo40[fold]['Results']['train_loss']

    epochs = range(1, len(val_loss) + 1)
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.axvline(x=int(metadata_zulo40[fold]['Results']['model_from_epoch'][:2]), color='g', linestyle='--')
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    

plt.tight_layout()
plt.show()
# Out:
# Fold 0
# Model stopped at epoch 23 with mae 0.9682469367980957
# Fold 1
# Model stopped at epoch 24 with mae 0.9842150211334229
# Fold 2
# Model stopped at epoch 22 with mae 1.1982290744781494

# %%
with open("ModelBuild/Metadata (efnet) 04/results.json") as json_file:
    metadata_zulo40 = json.load(json_file)

plt.figure(figsize=(15, 5))
plt.suptitle("Metadata 04 - Loss vs Epoch (menor learning rate 1e-5 e mais epochs)")
for fold in metadata_zulo40:
    print(f"{fold}")
    print(f"Model stopped at epoch {metadata_zulo40[fold]['Results']['model_from_epoch']}")

    plt.subplot(1, 3, int(fold.split(" ")[-1])+1)
    val_loss = metadata_zulo40[fold]['Results']['val_loss']
    train_loss = metadata_zulo40[fold]['Results']['train_loss']

    epochs = range(1, len(val_loss) + 1)
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.axvline(x=int(metadata_zulo40[fold]['Results']['model_from_epoch'][:2]), color='g', linestyle='--')
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    

plt.tight_layout()
plt.show()
# Out:
# Fold 0
# Model stopped at epoch 32 with mae 1.0273847579956055
# Fold 1
# Model stopped at epoch 74 with mae 1.3032989501953125
# Fold 2
# Model stopped at epoch 32 with mae 1.5605279207229614

# %%
with open("ModelBuild/Metadata (efnet) 05/results.json") as json_file:
    metadata_zulo40 = json.load(json_file)

plt.figure(figsize=(15, 5))
plt.suptitle("Metadata 04 - Loss vs Epoch (lr-4, droput40, cosine para dar update no lr diferente)")
for fold in metadata_zulo40:
    print(f"{fold}")
    print(f"Model stopped at epoch {metadata_zulo40[fold]['Results']['model_from_epoch']}")

    plt.subplot(1, 3, int(fold.split(" ")[-1])+1)
    val_loss = metadata_zulo40[fold]['Results']['val_loss']
    train_loss = metadata_zulo40[fold]['Results']['train_loss']

    epochs = range(1, len(val_loss) + 1)
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.axvline(x=int(metadata_zulo40[fold]['Results']['model_from_epoch'][:2]), color='g', linestyle='--')
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    

plt.tight_layout()
plt.show()
# Out:
# Fold 0
# Model stopped at epoch 40 with mae 1.1045701503753662
# Fold 1
# Model stopped at epoch 42 with mae 1.083322525024414
# Fold 2
# Model stopped at epoch 16 with mae 1.2846843004226685

# %%
with open("ModelBuild/metadata results_kaggle lre5 dropout40/results.json") as json_file:
    metadata_zulo40 = json.load(json_file)

plt.figure(figsize=(15, 5))
plt.suptitle("Metadata 04 - Loss vs Epoch (menor learning rate 1e-5 e mais epochs e dropout)")
for fold in metadata_zulo40:
    print(f"{fold}")
    print(f"Model stopped at epoch {metadata_zulo40[fold]['Results']['model_from_epoch']}")

    plt.subplot(1, 3, int(fold.split(" ")[-1])+1)
    val_loss = metadata_zulo40[fold]['Results']['val_loss']
    train_loss = metadata_zulo40[fold]['Results']['train_loss']

    epochs = range(1, len(val_loss) + 1)
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.plot(epochs, train_loss, 'b', label='Training Loss')
    plt.axvline(x=int(metadata_zulo40[fold]['Results']['model_from_epoch'][:2]), color='g', linestyle='--')
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    

plt.tight_layout()
plt.show()
# Out:
# Fold 2
# Model stopped at epoch 56 with mae 1.513322353363037
