# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json

# %% [markdown]
# ---

# %%
with open("ModelBuild/Metadata (efnet (zulo40))/results.json") as json_file:
    metadata_zulo40 = json.load(json_file)

for fold in metadata_zulo40:
    print(f"{fold}")
    print(f"Model stopped at epoch {metadata_zulo40[fold]['Results']['model_from_epoch']}")
    plt.figzize = (10, 10)
    val_loss = metadata_zulo40[fold]['Results']['val_loss']
    train_loss = metadata_zulo40[fold]['Results']['train_loss']

    plt.plot(val_loss, label='Validation Loss')
    plt.plot(train_loss, label='Training Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    print()
    print()
# Out:
# Fold 0
# Model stopped at epoch 22 with mae 1.2288780212402344
# Fold 1
# Model stopped at epoch 25 with mae 1.1219252347946167
# Fold 2
# Model stopped at epoch 19 with mae 1.270377516746521
